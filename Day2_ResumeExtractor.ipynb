# %% [markdown]
# <a href="https://colab.research.google.com/github/SindhuBangaru/ai-mentor-portfolio/blob/main/Day2_ResumeExtractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai pydantic
import os, getpass
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = getpass.getpass('Gemini API key: ')
# Out:
# Gemini API key: ··········

# %%
from pydantic import BaseModel
from typing import List, Optional

class Education(BaseModel):
    degree: str
    institution: str
    year: int

class Resume(BaseModel):
    name: str
    email: str
    phone: Optional[str] = None
    education: List[Education]
    skills: List[str]
    projects: List[str] = []
    experience_years: float

# %%
from google import genai
from pydantic import ValidationError

client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

def extract_resume(raw_text: str, max_retries: int = 1) -> Resume:
    for attempt in range(max_retries + 1):
        try:
            resp = client.models.generate_content(
                model='gemini-2.5-flash',
                contents=f'Extract a Resume JSON from this text. Return ONLY JSON, no markdown.\n\n{raw_text}',
                config={
                    'response_mime_type': 'application/json',
                    'response_schema': Resume.model_json_schema(),
                },
            )
            return Resume.model_validate_json(resp.text)
        except ValidationError as e:
            if attempt == max_retries:
                raise
            # Retry once with the broken JSON in the prompt
            fix_prompt = (f'Fix this JSON to match schema. Errors: {e}. '
                          f'Original: {resp.text}')
            resp = client.models.generate_content(
                model='gemini-2.5-flash', contents=fix_prompt,
                config={
                    'response_mime_type': 'application/json',
                    'response_schema': Resume.model_json_schema(),
                },
            )
            return Resume.model_validate_json(resp.text)

# %%
# Load sample résumés from the lab kit
with open('../bin/sample_resumes.txt') as f:
    resumes = [r.strip() for r in f.read().split('---') if r.strip()]

print(f'Loaded {len(resumes)} sample résumés')

results = []
for i, r in enumerate(resumes[:3]):
    try:
        parsed = extract_resume(r)
        results.append(parsed)
        print(f'\nRésumé {i+1}: {parsed.name} — {len(parsed.skills)} skills, '
              f'{parsed.experience_years} years exp')
    except Exception as e:
        print(f'\nRésumé {i+1}: FAILED — {type(e).__name__}: {str(e)[:200]}')

# Print full first result
if results:
    print('\n=== Full first result ===')
    print(results[0].model_dump_json(indent=2))
# Out:
# Loaded 5 sample résumés
#
# Résumé 1: Ravi Kumar — 6 skills, 0.25 years exp
#
# Résumé 2: Sneha Reddy — 6 skills, 0.115 years exp
#
# Résumé 3: Arun Pillai — 8 skills, 0.5 years exp
#
# === Full first result ===
# {
#   "name": "Ravi Kumar",
#   "email": "ravi.kumar@example.com",
#   "phone": "+91-9876543210",
#   "education": [
#     {
#       "degree": "B.Tech Computer Science",
#       "institution": "Aditya University",
#       "year": 2026
#     },
#     {
#       "degree": "Intermediate",
#       "institution": "Narayana Junior College",
#       "year": 2022
#     }
#   ],
#   "skills": [
#     "Python",
#     "Java",
#     "SQL",
#     "Git",
#     "Linux",
#     "REST APIs"
#   ],
#   "projects": [
#     "Built a Flask REST API for college placement portal",
#     "Solved 250+ DSA problems on LeetCode",
#     "Final-year project: ML model for crop yield prediction"
#   ],
#   "experience_years": 0.25
# }

# %%
# Empty string — should fail gracefully, not crash
try:
    bad = extract_resume('')
    print('Unexpected success:', bad.model_dump_json())
except Exception as e:
    print('Caught gracefully:', type(e).__name__)
    print('Message:', str(e)[:200])
# Out:
# Unexpected success: {"name":"John Doe","email":"john.doe@example.com","phone":"555-123-4567","education":[{"degree":"Master of Science in Computer Science","institution":"University of California, Berkeley","year":2022},{"degree":"Bachelor of Engineering in Software Engineering","institution":"University of Waterloo","year":2020}],"skills":["Python","Java","C++","AWS","Machine Learning","Data Structures","Algorithms","Full-stack Development"],"projects":["E-commerce Platform Development","AI-powered Chatbot","Distributed File System"],"experience_years":3.5}

# %%
import re
import json

# Read input file
with open("../bin/mcqs.txt", "r", encoding="utf-8") as f:
    text = f.read()

# Regex pattern
pattern = re.compile(
    r'(\d+)\.\s*(.*?)\n'
    r'A\.\s*(.*?)\n'
    r'B\.\s*(.*?)\n'
    r'C\.\s*(.*?)\n'
    r'D\.\s*(.*?)\n'
    r'Answer:\s*([A-D])',
    re.MULTILINE
)

mcqs = []

for match in pattern.finditer(text):
    mcq = {
        "id": int(match.group(1)),
        "question": match.group(2).strip(),
        "options": {
            "A": match.group(3).strip(),
            "B": match.group(4).strip(),
            "C": match.group(5).strip(),
            "D": match.group(6).strip()
        },
        "correct_answer": match.group(7).strip()
    }

    mcqs.append(mcq)

# Print complete JSON output
print(json.dumps(mcqs, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "id": 1,
#         "question": "Which data structure follows the LIFO principle?",
#         "options": {
#             "A": "Queue",
#             "B": "Stack",
#             "C": "Array",
#             "D": "Linked List"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "id": 2,
#         "question": "Which keyword is used to create a class in Java?",
#         "options": {
#             "A": "object",
#             "B": "struct",
#             "C": "class",
#             "D": "define"
#         },
#         "correct_answer": "C"
#     },
#     {
#         "id": 3,
#         "question": "What is the time complexity of binary search in a sorted array?",
#         "options": {
#             "A": "O(n)",
#             "B": "O(log n)",
#             "C": "O(n log n)",
#             "D": "O(1)"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "id": 4,
#         "question": "Which of the following is a primary key property in DBMS?",
#         "options": {
#             "A": "It can contain duplicate values",
#             "B": "It can contain NULL values",
#             "C": "It uniquely identifies each record",
#             "D": "It is used only for sorting"
#         },
#         "correct_answer": "C"
#     },
#     {
#         "id": 5,
#         "question": "Which protocol is mainly used to transfer web pages over the internet?",
#         "options": {
#             "A": "FTP",
#             "B": "HTTP",
#             "C": "SMTP",
#             "D": "TCP"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "id": 6,
#         "question": "Which concept allows the same function name to perform different tasks in OOP?",
#         "options": {
#             "A": "Encapsulation",
#             "B": "Inheritance",
#             "C": "Polymorphism",
#             "D": "Abstraction"
#         },
#         "correct_answer": "C"
#     },
#     {
#         "id": 7,
#         "question": "Which of the following is an operating system?",
#         "options": {
#             "A": "Oracle",
#             "B": "Windows",
#             "C": "Python",
#             "D": "HTML"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "id": 8,
#         "question": "In C programming, which symbol is used to access the address of a variable?",
#         "options": {
#             "A": "*",
#             "B": "&",
#             "C": "%",
#             "D": "#"
#         },
#         "correct_answer": "B"
#     },
#     {
#         "id": 9,
#         "question": "Which SQL command is used to retrieve data from a table?",
#         "options": {
#             "A": "INSERT",
#             "B": "UPDATE",
#             "C": "DELETE",
#             "D": "SELECT"
#         },
#         "correct_answer": "D"
#     },
#     {
#         "id": 10,
#         "question": "Which of the following is used to store multiple values of the same data type in C?",
#         "options": {
#             "A": "Function",
#             "B": "Array",
#             "C": "Pointer",
#             "D": "Structure"
#         },
#         "correct_answer": "B"
#     }
# ]
