# %% [markdown]
# <a href="https://colab.research.google.com/github/SindhuBangaru/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='what is a scopus journal.'
)
print(resp.text)
# Out:
# A **Scopus journal** is simply a journal that has been selected for inclusion and is indexed in the **Scopus database**.
#
# Let's break that down:
#
# 1.  **What is Scopus?**
#     Scopus is one of the world's largest **abstract and citation databases** of peer-reviewed literature. It's owned by Elsevier and covers a vast array of scientific, technical, medical, social sciences, arts, and humanities disciplines. It indexes:
#     *   Journals (tens of thousands)
#     *   Conference proceedings
#     *   Books
#     *   Patents
#
# 2.  **What does it mean for a journal to be "Scopus-indexed" or a "Scopus journal"?**
#     *   **Quality Assurance:** It signifies that the journal has met certain rigorous criteria for academic quality, editorial standards, and regular publication as evaluated by the independent Scopus Content Selection and Advisory Board (CSAB).
# ...
